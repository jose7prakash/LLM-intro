# %%
import pandas as pd
import numpy as np

# %%
bank = pd.read_csv('https://raw.githubusercontent.com/venkatareddykonasani/Datasets/master/Bank%20Tele%20Marketing/bank_market.csv')

# %%
two_col = np.array(bank[["age", "Cust_num", "balance", "loan"]])
print(two_col)
print('shape =' + str(two_col.shape))
print('dimensions =' + str(two_col.ndim))
print('data type =' + str(two_col.dtype))
print('size =' + str(two_col.size))

# %%
print((bank))
print('shape =' + str(bank.shape))
print('dimensions =' + str(bank.ndim))
print('data type =' + str(bank.dtypes))
print('size =' + str(bank.size))

# %%
two_vars = ['age', 'Cust_num', 'balance', 'loan']
two_col = np.array(bank[two_vars])
print(two_col)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 two_vars = [age, Cust_num, balance, loan]
#       2 two_col = np.array(bank[two_vars])
#       3 print(two_col)
#
# NameError: name 'Cust_num' is not defined
